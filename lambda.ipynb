# %% [markdown]
# <a href="https://colab.research.google.com/github/thirumalaivasan2401251-byte/pp-3/blob/main/lambda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = lambda x, y : (x * y)
print(a(4, 5))

a = lambda x, y : (x * y)
print(a(4, 5))

a = lambda x, y, z : (x + y + z)
print(a(4, 5, 5))
# Out:
# 20
# 20
# 14
