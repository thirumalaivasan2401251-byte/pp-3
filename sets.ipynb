# %% [markdown]
# <a href="https://colab.research.google.com/github/thirumalaivasan2401251-byte/pp-3/blob/main/sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Day = {"Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"}
for x in Day:
    print(x)
# Out:
# Thursday
# Wednesday
# Saturday
# Sunday
# Monday
# Friday
# Tuesday

# %%
Day = {"Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"}
print(Day)
print(type(Day))
print("looping through set elements")
for x in Day:
    print(x)
# Out:
# {'Thursday', 'Wednesday', 'Saturday', 'Sunday', 'Monday', 'Friday', 'Tuesday'}
# <class 'set'>
# looping through set elements
# Thursday
# Wednesday
# Saturday
# Sunday
# Monday
# Friday
# Tuesday

# %%
Day = set(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])
print(Day)
print(type(Day))
print("looping through set elements")
for x in Day:
    print(x)
# Out:
# {'Thursday', 'Wednesday', 'Saturday', 'Monday', 'Sunday', 'Friday', 'Tuesday'}
# <class 'set'>
# looping through set elements
# Thursday
# Wednesday
# Saturday
# Monday
# Sunday
# Friday
# Tuesday

# %%
set1 = {1,2,3,"javapoint",20.5,14}
print(set1)
print(type(set1))
# Out:
# {1, 2, 3, 'javapoint', 20.5, 14}
# <class 'set'>

# %%
set1 = {1,2,3,["javapoint",14],20.5,14}
print(set1)
print(type(set1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3036752797.py in <cell line: 0>()
# ----> 1 set1 = {1,2,3,["javapoint",14],20.5,14}
#       2 print(set1)
#       3 print(type(set1))
#
# TypeError: unhashable type: 'list'

# %%
month = {"January","February","March","April","May","June"}
print(month)
print(type(month))
# Out:
# {'February', 'April', 'January', 'June', 'March', 'May'}
# <class 'set'>

# %%
month = {"January","February","March","April","May","June"}
print(month)
month.add("july")
month.add("August")
print(month)
# Out:
# {'February', 'April', 'January', 'June', 'March', 'May'}
# {'February', 'july', 'April', 'January', 'June', 'March', 'August', 'May'}

# %%
month = {"January","February","March","April","May","June"}
print(month)
month.update(["july","August","September","October"])
print(month)
# Out:
# {'February', 'April', 'January', 'June', 'March', 'May'}
# {'April', 'June', 'March', 'February', 'july', 'January', 'August', 'October', 'September', 'May'}

# %%
month = {"January","February","March","April","May","June"}
print(month)
month.discard("January")
print(month)
# Out:
# {'February', 'April', 'January', 'June', 'March', 'May'}
# {'February', 'April', 'June', 'March', 'May'}

# %%
month = {"January","February","March","April","May","June"}
print(month)
month.remove("January")
print(month)
# Out:
# {'February', 'April', 'January', 'June', 'March', 'May'}
# {'February', 'April', 'June', 'March', 'May'}

# %%
month = {"January","February","March","April","May","June"}
print(month)
month.pop()
month.pop()
print(month)
# Out:
# {'February', 'April', 'January', 'June', 'March', 'May'}
# {'January', 'June', 'March', 'May'}

# %%
month = set(["January","February","March","April","May","June"])
print(month)
month.clear()
print(month)
# Out:
# {'April', 'June', 'March', 'February', 'January', 'May'}
# set()

# %%
month = set(["January","February","March","April","May","June"])
print(month)
month.discard("January")
print(month)
month.discard("July")
print(month)
# Out:
# {'April', 'June', 'March', 'February', 'January', 'May'}
# {'April', 'June', 'March', 'February', 'May'}
# {'April', 'June', 'March', 'February', 'May'}

# %%
month1 = {"January","February","March","April","May","June"}
month2 = {"July","August","September","October","November","December"}
print(month1|month2)
# Out:
# {'November', 'April', 'June', 'March', 'October', 'July', 'February', 'December', 'August', 'January', 'September', 'May'}

# %%
month1 = {"January","February","March","April","May","June"}
month2 = {"July","August","September","October","November","December"}
print(month1.union(month2))
# Out:
# {'November', 'April', 'June', 'March', 'October', 'July', 'February', 'December', 'August', 'January', 'September', 'May'}

# %%
month1 = {"January","February","March","April","May","June"}
month2 = {"July","August","April","October","November","December"}
print(month1&month2)
# Out:
# {'April'}

# %%
month1 = {"January","February","March","April","May","June"}
month2 = {"July","August","April","October","November","December"}
print(month1.intersection(month2))
# Out:
# {'April'}

# %%
month2 = {"January","February","March","April"}
month1 = {"February","April","October","November","December"}
print(month1-month2)
# Out:
# {'December', 'November', 'October'}

# %%
month2 = {"January","February","March","April"}
month1 = {"February","April","October","November","December"}
print(month1.difference(month2))
# Out:
# {'December', 'November', 'October'}

# %%
a = {1,2,3,4,5}
b = {3,4,5,6,7}
print(a^b)
# Out:
# {1, 2, 6, 7}

# %%
a = {1,2,3,4,5}
b = {3,4,5,6,7}
print(a.symmetric_difference(b))
# Out:
# {1, 2, 6, 7}
